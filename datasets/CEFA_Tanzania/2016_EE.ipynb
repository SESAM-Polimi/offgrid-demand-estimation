# %% [markdown]
# # CEFA 2016 EE dataset
# This notebook is used to create the dataset for CEFA 2016 EE. The dataset consists of multiple files.
# - Q_EE_HH_Results_General
# - GADM_level_0
# - GADM_level_1
# - GADM_level_2

# %%
import os
import sys
import pandas as pd
import numpy as np

sys.path.append("../../")  # Adds higher directory to python modules path.
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
from core.ODEDataset import ODEDataset
from utils import common_modifiers,  appliances_modifiers, geospatial

import pathlib
from utils import constants

# %%
DB_ROOT = "../../playground/data/CEFA_Tanzania/2016_EE"
root = pathlib.Path(DB_ROOT)

ID_COL = "ID"

# %% [markdown]
# ## Clusters
# Clusters are group of columns used together to create a new feature.

# %% [markdown]
# ## Categories
# Map the original values to the standard values.

# %%
Education_level_original2final = {'P': 'Primary education',
                                    'S': 'Lower secondary education',
                                    'U': 'Bachelor\'s or equivalent level'}

Socio_status_original2final = {
    'Agr': 'Own-account worker farm',
    'Bre': 'Own-account worker farm',
    'Self': 'Own-account worker non-farm',
    'Sal': 'Employee non-farm',
}

Tariff_payment_frequency_original2final = {
    'W': 'Weekly',
    'M': 'Monthly',
    'M3': 'Every 3 months',
}

# %% [markdown]
# ## Q_EE_HH_Results_General

# %% [markdown]
# ### Merge Q_EE_HH_Results_General, Q_EE_PS_Results_General, Q_EE_US_Results_General

# %%
Q_EE_HH_Results_General = ODEDataset("Q_EE_HH_Results_General")
Q_EE_PS_Results_General = ODEDataset("Q_EE_PS_Results_General")
Q_EE_US_Results_General = ODEDataset("Q_EE_US_Results_General")

Q_EE_HH_Results_General.from_excel(root.joinpath("Q_EE_HH_Results_General.xlsx"))

Q_EE_HH_Results_General = Q_EE_HH_Results_General.apply(common_modifiers.rename({
    "Q_EE_HH": ID_COL,
    "HH_size": "size",
    "HH_rooms": "rooms",
    "HH_members": "members",
}))

# Columns present in PS and US
Q_EE_HH_Results_General = Q_EE_HH_Results_General.apply(common_modifiers.add_const_driver_many({
    "Class": np.nan,
    "Role": np.nan,
    "number": np.nan,
    "Consumption": np.nan,
}))

Q_EE_PS_Results_General.from_excel(root.joinpath("Q_EE_PS_Results_General.xlsx"))
Q_EE_PS_Results_General = Q_EE_PS_Results_General.apply(common_modifiers.rename({
    "Q_EE_PS": ID_COL,
    "PS_size": "size",
    "PS_number": "number",
}))

# Columns  present in HH
Q_EE_PS_Results_General = Q_EE_PS_Results_General.apply(common_modifiers.add_const_driver_many({
    'members': np.nan,
    'rooms': np.nan,
    'Income_source': np.nan,
    'Income': np.nan,
    'Expenditures': np.nan,
}))

Q_EE_US_Results_General.from_excel(root.joinpath("Q_EE_US_Results_General.xlsx"))
Q_EE_US_Results_General = Q_EE_US_Results_General.apply(common_modifiers.rename({
    "Q_EE_US": ID_COL,
    "US_size": "size",
    "US_number": "number"
}))

# Columns  present in HH
Q_EE_US_Results_General = Q_EE_US_Results_General.apply(common_modifiers.add_const_driver_many({
    'members': np.nan,
    'rooms': np.nan,
    'Income_source': np.nan,
    'Income': np.nan,
    'Expenditures': np.nan,
}))

Q_Results_General = Q_EE_HH_Results_General.concat(Q_EE_PS_Results_General).concat(Q_EE_US_Results_General)
Q_Results_General = Q_Results_General.group_by(ID_COL)
Q_Results_General.preview(2000)
# Out:
#             ID       Village          Interviewee   Age  Sex Education  \
# 0   Q_EE_HH_01      [Nyombo]    [Anastasia Mbata]  [44]  [F]       [P]
# 1   Q_EE_HH_02      [Nyombo]           [Chongolo]  [42]  [M]       [P]
# 2   Q_EE_HH_03      [Nyombo]              [Bahat]  [35]  [M]       [P]
# 3   Q_EE_HH_04      [Nyombo]              [Nyahi]  [32]  [F]       [P]
# 4   Q_EE_HH_05      [Nyombo]            [Mwinami]  [30]  [F]       [P]
# 5   Q_EE_HH_06      [Nyombo]              [Jesca]  [37]  [F]       [P]
# 6   Q_EE_HH_07      [Nyombo]             [Kaduma]  [38]  [M]       [P]
# 7   Q_EE_HH_08      [Nyombo]            [Leonadi]  [45]  [M]       [P]
# 8   Q_EE_HH_09      [Nyombo]            [Rosalia]  [38]  [F]       [P]
# 9   Q_EE_HH_10      [Nyombo]              [Jared]  [35]  [M]       [P]
# 10  Q_EE_HH_11      [Nyombo]              [James]  [21]  [M]       [S]
# 11  Q_EE_HH_12      [Nyombo]          [Ezechiele]  [35]  [M]       [S]
# 12  Q_EE_HH_13      [Nyombo]             [Venans]  [58]  [M]       [P]
# 13  Q_EE_HH_14      [Nyombo]             [Mwenda]  [70]  [M]       [P]
# 14  Q_EE_HH_15      [Nyombo]           [Chongolo]  [54]  [F]       [P]
# 15  Q_EE_HH_16      [Nyombo]            [Mfugale]  [43]  [F]       [P]
# 16  Q_EE_HH_17      [Nyombo]             [Victor]  [30]  [M]       [S]
# 17  Q_EE_HH_18      [Nyombo]              [David]  [60]  [M]       [S]
# 18  Q_EE_HH_19      [Nyombo]                [Ana]  [39]  [F]       [P]
# 19  Q_EE_HH_20      [Nyombo]               [Ana2]  [30]  [F]       [P]
# 20  Q_EE_HH_21      [Nyombo]                [Ida]  [35]  [F]       [P]
# 21  Q_EE_HH_22      [Nyombo]              [Jesko]  [35]  [M]       [P]
# 22  Q_EE_HH_23      [Nyombo]                [Atu]  [37]  [F]       [P]
# 23  Q_EE_HH_24      [Nyombo]               [Jene]  [37]  [F]       [P]
# 24  Q_EE_HH_25  [Kidegembye]              [Karas]  [33]  [M]       [P]
# 25  Q_EE_HH_26  [Kidegembye]              [Fredy]  [32]  [M]       [P]
# 26  Q_EE_HH_27  [Kidegembye]           [Kastiria]  [25]  [F]       [S]
# 27  Q_EE_HH_28  [Kidegembye]              [Irene]  [28]  [F]       [P]
# 28  Q_EE_HH_29  [Kidegembye]           [Shadrack]  [39]  [M]       [P]
# 29  Q_EE_HH_30  [Kidegembye]             [Oresta]  [24]  [F]       [S]
# 30  Q_EE_HH_31  [Kidegembye]        [Evangelista]  [39]  [F]       [P]
# 31  Q_EE_HH_32  [Kidegembye]             [Shaibu]  [37]  [M]       [P]
# 32  Q_EE_HH_33  [Kidegembye]             [Melisa]  [33]  [F]       [P]
# 33  Q_EE_PS_01      [Nyombo]       [Rukia Mlyuka]  [44]  [F]       [S]
# 34  Q_EE_PS_02      [Nyombo]      [Joseph Mkinye]  [57]  [M]       [P]
# 35  Q_EE_PS_03      [Nyombo]       [Dina Fanueli]  [29]  [F]       [U]
# 36  Q_EE_PS_04  [Kidegembye]           [Geoffrey]  [34]  [M]       [U]
# 37  Q_EE_US_01      [Nyombo]     [Ayubu Chongolo]  [25]  [M]       [S]
# 38  Q_EE_US_02      [Nyombo]  [Heriberta kihombo]  [40]  [F]       [P]
# 39  Q_EE_US_03      [Nyombo]    [Ostakyus Mwenda]  [38]  [M]       [P]
# 40  Q_EE_US_04      [Nyombo]          [Luta Titu]  [19]  [M]       [P]
# 41  Q_EE_US_05      [Nyombo]         [Luka Mhada]  [27]  [M]       [P]
# 42  Q_EE_US_06      [Nyombo]          [Luta Titu]  [19]  [M]       [P]
# 43  Q_EE_US_07      [Nyombo]      [Joseph Mkinye]  [57]  [M]       [P]
# 44  Q_EE_US_08      [Nyombo]        [Neli Oswadi]  [22]  [F]       [S]
# 45  Q_EE_US_09      [Nyombo]        [Neli Oswadi]  [22]  [F]       [S]
# 46  Q_EE_US_10      [Nyombo]      [Benito Mwenda]  [41]  [M]       [P]
# 47  Q_EE_US_11      [Nyombo]       [Freddy Nyahi]  [24]  [M]       [P]
# 48  Q_EE_US_12      [Nyombo]      [Haluni Lameck]  [25]  [M]       [P]
# 49  Q_EE_US_13      [Nyombo]     [Alfredi Kaduma]  [41]  [M]       [P]
# 50  Q_EE_US_14  [Kidegembye]             [Julias]  [32]  [M]       [P]
# 51  Q_EE_US_15  [Kidegembye]             [Faraja]  [27]  [F]       [P]
# 52  Q_EE_US_16  [Kidegembye]              [Fredy]  [32]  [M]       [P]
# 53  Q_EE_US_17  [Kidegembye]             [Yusuph]  [21]  [M]       [P]
# 54  Q_EE_US_18  [Kidegembye]            [Remidio]  [25]  [M]       [S]
#
#    members   rooms     size Income_source       Income Expenditures  \
# 0    [5.0]  [10.0]  [100.0]         [Agr]    [30000.0]    [10000.0]
# 1    [6.0]   [7.0]   [35.0]         [Agr]   [100000.0]   [100000.0]
# 2    [6.0]   [4.0]   [20.0]         [Agr]    [20000.0]    [20000.0]
# 3    [6.0]   [7.0]   [50.0]         [Bre]   [100000.0]   [100000.0]
# 4    [2.0]   [4.0]   [30.0]        [Self]   [100000.0]    [40000.0]
# 5    [7.0]   [7.0]   [80.0]         [Agr]    [30000.0]    [30000.0]
# 6    [5.0]   [8.0]   [70.0]         [Agr]    [35000.0]    [30000.0]
# 7    [6.0]   [3.0]   [30.0]         [Agr]    [30000.0]    [25000.0]
# 8    [4.0]   [8.0]   [50.0]         [Agr]   [200000.0]   [100000.0]
# 9    [3.0]   [7.0]   [60.0]         [Agr]    [60000.0]    [35000.0]
# 10   [9.0]  [10.0]   [80.0]        [Self]  [2000000.0]  [2000000.0]
# 11   [5.0]   [4.0]   [30.0]        [Self]   [100000.0]    [40000.0]
# 12   [8.0]   [7.0]   [90.0]         [Agr]    [48000.0]    [45000.0]
# 13   [7.0]   [8.0]   [60.0]         [Agr]   [190000.0]   [120000.0]
# 14   [5.0]  [10.0]  [100.0]         [Agr]    [60000.0]    [45000.0]
# 15   [5.0]  [10.0]  [100.0]         [Agr]    [35000.0]    [25000.0]
# 16   [5.0]   [4.0]   [50.0]        [Self]   [600000.0]   [500000.0]
# 17   [1.0]   [4.0]   [45.0]         [Sal]   [400000.0]   [300000.0]
# 18   [6.0]   [8.0]   [70.0]         [Agr]    [35000.0]    [18000.0]
# 19   [5.0]  [10.0]  [100.0]         [Agr]   [500000.0]   [200000.0]
# 20   [4.0]   [4.0]   [32.0]         [Agr]   [400000.0]    [40000.0]
# 21   [3.0]   [6.0]   [55.0]         [Agr]   [120000.0]    [80000.0]
# 22   [7.0]   [6.0]   [55.0]         [Agr]    [50000.0]    [50000.0]
# 23   [7.0]  [10.0]   [80.0]         [Agr]   [100000.0]    [50000.0]
# 24   [4.0]   [5.0]   [30.0]        [Self]   [300000.0]   [150000.0]
# 25   [8.0]   [4.0]   [75.0]        [Self]   [150000.0]   [100000.0]
# 26   [3.0]   [3.0]   [20.0]         [Sal]   [350000.0]   [150000.0]
# 27   [3.0]   [7.0]   [45.0]         [Agr]    [50000.0]    [30000.0]
# 28   [5.0]   [8.0]   [50.0]         [Agr]   [100000.0]    [80000.0]
# 29   [5.0]  [45.0]    [1.0]        [Self]   [300000.0]   [250000.0]
# 30   [6.0]  [12.0]   [60.0]         [Agr]   [100000.0]    [80000.0]
# 31   [7.0]   [8.0]   [60.0]         [Agr]   [500000.0]   [250000.0]
# 32   [6.0]   [7.0]   [45.0]         [Agr]   [150000.0]   [100000.0]
# 33   [nan]   [nan]  [300.0]         [nan]        [nan]        [nan]
# 34   [nan]   [nan]  [300.0]         [nan]        [nan]        [nan]
# 35   [nan]   [nan]  [100.0]         [nan]        [nan]        [nan]
# 36   [nan]   [nan]  [500.0]         [nan]        [nan]        [nan]
# 37   [nan]   [nan]   [15.0]         [nan]        [nan]        [nan]
# 38   [nan]   [nan]    [6.0]         [nan]        [nan]        [nan]
# 39   [nan]   [nan]  [120.0]         [nan]        [nan]        [nan]
# 40   [nan]   [nan]   [18.0]         [nan]        [nan]        [nan]
# 41   [nan]   [nan]   [30.0]         [nan]        [nan]        [nan]
# 42   [nan]   [nan]    [7.0]         [nan]        [nan]        [nan]
# 43   [nan]   [nan]   [45.0]         [nan]        [nan]        [nan]
# 44   [nan]   [nan]   [30.0]         [nan]        [nan]        [nan]
# 45   [nan]   [nan]   [25.0]         [nan]        [nan]        [nan]
# 46   [nan]   [nan]   [21.0]         [nan]        [nan]        [nan]
# 47   [nan]   [nan]   [25.0]         [nan]        [nan]        [nan]
# 48   [nan]   [nan]    [9.0]         [nan]        [nan]        [nan]
# 49   [nan]   [nan]    [8.0]         [nan]        [nan]        [nan]
# 50   [nan]   [nan]   [10.0]         [nan]        [nan]        [nan]
# 51   [nan]   [nan]  [150.0]         [nan]        [nan]        [nan]
# 52   [nan]   [nan]   [20.0]         [nan]        [nan]        [nan]
# 53   [nan]   [nan]    [6.0]         [nan]        [nan]        [nan]
# 54   [nan]   [nan]    [6.0]         [nan]        [nan]        [nan]
#
#    Bill_schedule      Bill                                           Comments  \
# 0            [M]   [48000]                                [Frequent cut-offs]
# 1            [M]   [30000]        [Frequent cut-offs; Slow repairing service]
# 2            [M]   [10000]                                [Frequent cut-offs]
# 3            [M]   [20000]                                          [Nothing]
# 4            [M]   [12000]                          [Don't know/don't answer]
# 5            [M]   [17000]                                [Frequent cut-offs]
# 6            [M]   [20000]                          [Don't know/don't answer]
# 7            [M]    [7000]              [Electricity cost; Frequent cut-offs]
# 8            [W]   [40000]                                [Frequent cut-offs]
# 9            [M]   [15000]                                [Frequent cut-offs]
# 10           [M]   [25000]                                [Frequent cut-offs]
# 11           [M]   [12000]      [Slow repairing service; Frequent cut-offs; ]
# 12           [M]   [10000]        [Frequent cut-offs; Slow repairing service]
# 13           [M]   [15000]        [Frequent cut-offs; Slow repairing service]
# 14           [M]   [13000]                                [Frequent cut-offs]
# 15           [M]   [10000]                                [Frequent cut-offs]
# 16           [M]   [18000]        [Frequent cut-offs; Slow repairing service]
# 17           [M]   [25000]              [Electricity cost; Frequent cut-offs]
# 18           [W]   [16000]                                [Frequent cut-offs]
# 19           [M]   [18000]                                [Frequent cut-offs]
# 20           [M]   [15000]                          [Don't know/don't answer]
# 21           [M]   [12000]                          [Don't know/don't answer]
# 22          [M3]   [10000]                                [Frequent cut-offs]
# 23           [M]   [17000]                                [Frequent cut-offs]
# 24           [M]   [15000]  [Frequent cut-offs; Voltage instability; Slow ...
# 25           [M]   [10000]                                [Frequent cut-offs]
# 26           [M]   [20000]                                [Frequent cut-offs]
# 27           [M]   [10000]                                [Frequent cut-offs]
# 28           [M]   [15000]                              [Voltage instability]
# 29           [M]   [20000]                                [Frequent cut-offs]
# 30           [M]   [15000]                                [Frequent cut-offs]
# 31           [M]   [30000]           [Frequent cut-offs; Voltage instability]
# 32           [M]   [20000]           [Frequent cut-offs; Unreliable metering]
# 33           [M]  [100000]           [Frequent cut-offs; Voltage instability]
# 34           [M]   [80000]                                [Frequent cut-offs]
# 35           [M]   [45000]        [Frequent cut-offs; Slow repairing service]
# 36           [M]  [231000]  [Insufficient electric coverage; Voltage insta...
# 37           [M]   [60000]                                [Frequent cut-offs]
# 38           [M]    [4000]                                [Frequent cut-offs]
# 39           [M]  [100000]             [Frequent cut-offs; High service fees]
# 40           [M]  [100000]                                [Frequent cut-offs]
# 41           [M]  [150000]                                [Frequent cut-offs]
# 42           [M]    [5000]                                [Frequent cut-offs]
# 43           [M]   [50000]                                [Frequent cut-offs]
# 44           [M]   [20000]                                              [nan]
# 45           [M]   [12000]                                              [nan]
# 46           [M]   [52000]  [Frequent cut-offs; Slow assistance service; H...
# 47           [M]   [14000]                                              [nan]
# 48           [M]   [10000]                                [High service fees]
# 49           [M]    [6000]             [High service fees; Frequent cut-offs]
# 50           [M]   [25000]                                [Frequent cut-offs]
# 51           [M]   [30000]                                              [nan]
# 52           [M]   [20000]                                [Frequent cut-offs]
# 53           [M]   [23000]                                              [nan]
# 54           [M]   [20000]                                [Frequent cut-offs]
#
#             Class        Role   number   Consumption
# 0           [nan]       [nan]    [nan]         [nan]
# 1           [nan]       [nan]    [nan]         [nan]
# 2           [nan]       [nan]    [nan]         [nan]
# 3           [nan]       [nan]    [nan]         [nan]
# 4           [nan]       [nan]    [nan]         [nan]
# 5           [nan]       [nan]    [nan]         [nan]
# 6           [nan]       [nan]    [nan]         [nan]
# 7           [nan]       [nan]    [nan]         [nan]
# 8           [nan]       [nan]    [nan]         [nan]
# 9           [nan]       [nan]    [nan]         [nan]
# 10          [nan]       [nan]    [nan]         [nan]
# 11          [nan]       [nan]    [nan]         [nan]
# 12          [nan]       [nan]    [nan]         [nan]
# 13          [nan]       [nan]    [nan]         [nan]
# 14          [nan]       [nan]    [nan]         [nan]
# 15          [nan]       [nan]    [nan]         [nan]
# 16          [nan]       [nan]    [nan]         [nan]
# 17          [nan]       [nan]    [nan]         [nan]
# 18          [nan]       [nan]    [nan]         [nan]
# 19          [nan]       [nan]    [nan]         [nan]
# 20          [nan]       [nan]    [nan]         [nan]
# 21          [nan]       [nan]    [nan]         [nan]
# 22          [nan]       [nan]    [nan]         [nan]
# 23          [nan]       [nan]    [nan]         [nan]
# 24          [nan]       [nan]    [nan]         [nan]
# 25          [nan]       [nan]    [nan]         [nan]
# 26          [nan]       [nan]    [nan]         [nan]
# 27          [nan]       [nan]    [nan]         [nan]
# 28          [nan]       [nan]    [nan]         [nan]
# 29          [nan]       [nan]    [nan]         [nan]
# 30          [nan]       [nan]    [nan]         [nan]
# 31          [nan]       [nan]    [nan]         [nan]
# 32          [nan]       [nan]    [nan]         [nan]
# 33       [School]   [Teacher]  [433.0]       [352.0]
# 34           [PO]   [Manager]   [14.0]       [277.0]
# 35         [Disp]  [Daughter]   [12.0]         [nan]
# 36       [School]   [Teacher]  [450.0]         [nan]
# 37        [Mills]     [Owner]    [3.0]  [Don't know]
# 38         [Shop]     [Owner]    [1.0]  [Don't know]
# 39          [Pub]     [Owner]    [2.0]  [Don't know]
# 40        [Mills]    [Worker]    [1.0]  [Don't know]
# 41        [Mills]    [Worker]    [1.0]  [Don't know]
# 42         [Shop]    [Worker]    [2.0]  [Don't know]
# 43         [Shop]   [Manager]    [2.0]  [Don't know]
# 44  [Guest_house]    [Worker]    [1.0]  [Don't know]
# 45          [Pub]    [Worker]    [3.0]  [Don't know]
# 46    [Carpentry]     [Owner]   [10.0]   [180 units]
# 47       [Garage]     [Owner]    [4.0]    [45 units]
# 48         [Shop]     [Owner]    [1.0]  [Don't know]
# 49  [Hair_cutter]     [Owner]    [1.0]    [18 units]
# 50       [Garage]     [Owner]    [2.0]  [Don't know]
# 51  [Guest_house]     [Owner]    [1.0]  [Don't know]
# 52    [Carpentry]     [Owner]    [3.0]  [Don't know]
# 53  [Hair_cutter]    [Worker]    [1.0]  [Don't know]
# 54  [Hair_cutter]     [Owner]    [1.0]  [Don't know]

# %% [markdown]
# ### GeoSpatial Information

# %%
gadm_level_1_df = pd.read_excel(root.joinpath("GADM_level_1.xlsx"))
gadm_level_2_df = pd.read_excel(root.joinpath("GADM_level_2.xlsx"))
gadm_level_3_df = pd.read_excel(root.joinpath("GADM_level_3.xlsx"))

village_gps_info_df = pd.read_excel(root.joinpath("Village_GPS_info.xlsx"))

# %%
Q_Results_General = Q_Results_General.new_feature("Township/Village",
                                                  lambda row: row["Village"][0])

Q_Results_General = Q_Results_General.new_feature("GADM_level_1",
                                                  geospatial.gis_info_by_village_level("GADM_level_1",
                                                                                       village_gps_info_df))

Q_Results_General = Q_Results_General.new_feature("GADM_level_2",
                                                  geospatial.gis_info_by_village_level("GADM_level_2",
                                                                                       village_gps_info_df))

Q_Results_General = Q_Results_General.new_feature("GADM_level_3",
                                                  geospatial.gis_info_by_village_level("GADM_level_3",
                                                                                       village_gps_info_df))

Q_Results_General = Q_Results_General.new_feature("Climate_zone_lev_1",
                                                  geospatial.gis_info_by_gadm_level('Climate_majority',
                                                                                    gadm_level_1_df,
                                                                                    'GADM_level_1'))
Q_Results_General = Q_Results_General.new_feature("Climate_zone_lev_2",
                                                  geospatial.gis_info_by_gadm_level('Climate_majority',
                                                                                    gadm_level_2_df,
                                                                                    'GADM_level_2'))

# %%
Q_Results_General = Q_Results_General.apply(common_modifiers.rename({
    "rooms": "Number_of_rooms"
})).apply(common_modifiers.take("Number_of_rooms", 0))

Q_Results_General = Q_Results_General.apply(common_modifiers.rename({
    "Income": "Income_of_household"
})).apply(common_modifiers.take("Income_of_household", 0))

Q_Results_General = Q_Results_General.apply(common_modifiers.rename({
    "Expenditures": "Monthly_expenditure"
})).apply(common_modifiers.take("Monthly_expenditure", 0))


Q_Results_General = Q_Results_General.new_feature("Number_adults",
                                                  lambda x: x["members"][0] * 0.535)

Q_Results_General = Q_Results_General.new_feature("Socio_status_HHH",
                                                  common_modifiers.categorize("Income_source",
                                                                              Socio_status_original2final)).apply(
    common_modifiers.take("Socio_status_HHH", 0))

Q_Results_General = Q_Results_General.new_feature("Education_level_HHH",
                                                  common_modifiers.categorize("Education",
                                                                              Education_level_original2final)).apply(
    common_modifiers.take("Education_level_HHH", 0))

Q_Results_General = Q_Results_General.apply(common_modifiers.add_const_driver_many({
    "Measurement_age": 2,
    "Connection_type": "National grid",  # needed to extract Monthly_expenditure
}))


Q_Results_General = Q_Results_General.new_feature("Tariff_payment_frequency",
                                                  common_modifiers.categorize("Bill_schedule",
                                                                              Tariff_payment_frequency_original2final)).apply(
    common_modifiers.take("Tariff_payment_frequency", 0))

Q_Results_General.preview()
# Out:
#            ID   Village        Interviewee   Age  Sex Education members  \
# 0  Q_EE_HH_01  [Nyombo]  [Anastasia Mbata]  [44]  [F]       [P]   [5.0]
# 1  Q_EE_HH_02  [Nyombo]         [Chongolo]  [42]  [M]       [P]   [6.0]
# 2  Q_EE_HH_03  [Nyombo]            [Bahat]  [35]  [M]       [P]   [6.0]
# 3  Q_EE_HH_04  [Nyombo]            [Nyahi]  [32]  [F]       [P]   [6.0]
# 4  Q_EE_HH_05  [Nyombo]          [Mwinami]  [30]  [F]       [P]   [2.0]
#
#    Number_of_rooms     size Income_source  ...  GADM_level_2  GADM_level_3  \
# 0             10.0  [100.0]         [Agr]  ...        Njombe         Ikuna
# 1              7.0   [35.0]         [Agr]  ...        Njombe         Ikuna
# 2              4.0   [20.0]         [Agr]  ...        Njombe         Ikuna
# 3              7.0   [50.0]         [Bre]  ...        Njombe         Ikuna
# 4              4.0   [30.0]        [Self]  ...        Njombe         Ikuna
#
#   Climate_zone_lev_1 Climate_zone_lev_2 Number_adults  \
# 0                 12                 12         2.675
# 1                 12                 12         3.210
# 2                 12                 12         3.210
# 3                 12                 12         3.210
# 4                 12                 12         1.070
#
#               Socio_status_HHH Education_level_HHH Measurement_age  \
# 0      Own-account worker farm   Primary education               2
# 1      Own-account worker farm   Primary education               2
# 2      Own-account worker farm   Primary education               2
# 3      Own-account worker farm   Primary education               2
# 4  Own-account worker non-farm   Primary education               2
#
#   Connection_type Tariff_payment_frequency
# 0   National grid                  Monthly
# 1   National grid                  Monthly
# 2   National grid                  Monthly
# 3   National grid                  Monthly
# 4   National grid                  Monthly
#
# [5 rows x 31 columns]

# %%
Q_Results_General = Q_Results_General.select(
    [ID_COL, 'Monthly_expenditure',
     'Socio_status_HHH', 'Number_of_rooms', 'Number_adults',
     'Measurement_age', 'Tariff_payment_frequency',
     'Education_level_HHH', 'Income_of_household',
     'Climate_zone_lev_1', 'Climate_zone_lev_2'])

# %%
Q_Results_General.preview()
# Out:
#            ID  Monthly_expenditure             Socio_status_HHH  \
# 0  Q_EE_HH_01              10000.0      Own-account worker farm
# 1  Q_EE_HH_02             100000.0      Own-account worker farm
# 2  Q_EE_HH_03              20000.0      Own-account worker farm
# 3  Q_EE_HH_04             100000.0      Own-account worker farm
# 4  Q_EE_HH_05              40000.0  Own-account worker non-farm
#
#    Number_of_rooms  Number_adults  Measurement_age Tariff_payment_frequency  \
# 0             10.0          2.675                2                  Monthly
# 1              7.0          3.210                2                  Monthly
# 2              4.0          3.210                2                  Monthly
# 3              7.0          3.210                2                  Monthly
# 4              4.0          1.070                2                  Monthly
#
#   Education_level_HHH  Income_of_household  Climate_zone_lev_1  \
# 0   Primary education              30000.0                  12
# 1   Primary education             100000.0                  12
# 2   Primary education              20000.0                  12
# 3   Primary education             100000.0                  12
# 4   Primary education             100000.0                  12
#
#    Climate_zone_lev_2
# 0                  12
# 1                  12
# 2                  12
# 3                  12
# 4                  12

# %% [markdown]
# ## Appliances
# General Appliances sections
# - Presence_phone_charger
# - Presence_iron
# - Presence_TV
# - Presence_refrigerator/freezer
# - Presence_radio/stereo
# - Presence_DVD_player
# - Presence_fan

# %% [markdown]
# ### Merge Q_EE_HH_Results_Appliances, Q_EE_PS_Results_Appliances, Q_EE_US_Results_Appliances

# %%
Q_EE_HH_Results_Appliances = ODEDataset("Q_EE_HH_Results_Appliances")
Q_EE_PS_Results_Appliances = ODEDataset("Q_EE_PS_Results_Appliances")
Q_EE_US_Results_Appliances = ODEDataset("Q_EE_US_Results_Appliances")

Q_EE_HH_Results_Appliances.from_excel(root.joinpath("Q_EE_HH_Results_Appliances.xlsx"))
Q_EE_PS_Results_Appliances.from_excel(root.joinpath("Q_EE_PS_Results_Appliances.xlsx"))
Q_EE_US_Results_Appliances.from_excel(root.joinpath("Q_EE_US_Results_Appliances.xlsx"))


Q_EE_HH_Results_Appliances.drop_columns(['Comments_old'])
Q_EE_PS_Results_Appliances.drop_columns(['Comments_old'])


# 
# 
Q_EE_HH_Results_Appliances = Q_EE_HH_Results_Appliances.apply(common_modifiers.rename({
    "Q_EE_HH": ID_COL,
})).group_by(ID_COL)


Q_EE_PS_Results_Appliances = Q_EE_PS_Results_Appliances.apply(common_modifiers.rename({
    "Q_EE_PS": ID_COL,
})).group_by(ID_COL)


Q_EE_US_Results_Appliances = Q_EE_US_Results_Appliances.apply(common_modifiers.rename({
    "Q_EE_US": ID_COL,
})).group_by(ID_COL)

# %%
print("HH Appliances")
print("Not in PS", [i for i in Q_EE_HH_Results_Appliances.get_columns() if i not in Q_EE_PS_Results_Appliances.get_columns()])
print("Not in US", [i for i in Q_EE_HH_Results_Appliances.get_columns() if i not in Q_EE_US_Results_Appliances.get_columns()])
print("PS Appliances")
print("Not in HH", [i for i in Q_EE_PS_Results_Appliances.get_columns() if i not in Q_EE_HH_Results_Appliances.get_columns()])
print("Not in US", [i for i in Q_EE_PS_Results_Appliances.get_columns() if i not in Q_EE_US_Results_Appliances.get_columns()])
print("US Appliances")
print("Not in HH", [i for i in Q_EE_US_Results_Appliances.get_columns() if i not in Q_EE_HH_Results_Appliances.get_columns()])
print("Not in PS", [i for i in Q_EE_US_Results_Appliances.get_columns() if i not in Q_EE_PS_Results_Appliances.get_columns()])
# Out:
# HH Appliances
# Not in PS []
# Not in US []
# PS Appliances
# Not in HH []
# Not in US []
# US Appliances
# Not in HH []
# Not in PS []

# %%
Appliances = Q_EE_HH_Results_Appliances.concat(Q_EE_PS_Results_Appliances).concat(Q_EE_US_Results_Appliances)

Appliances.preview()
# Out:
#            ID                                               Item  \
# 0  Q_EE_HH_01       [Charger, Ind_lights, Out_lights, Radio, TV]
# 1  Q_EE_HH_02       [Charger, Ind_lights, Out_lights, Radio, TV]
# 2  Q_EE_HH_03       [Charger, Ind_lights, Out_lights, Radio, TV]
# 3  Q_EE_HH_04                              [Charger, Ind_lights]
# 4  Q_EE_HH_05  [Charger, Ind_lights, Iron, Out_lights, Radio,...
#
#                   Item_power         Item_number  \
# 0        [5, 18, 18, 10, 80]     [4, 5, 2, 1, 1]
# 1        [5, 18, 18, 10, 80]     [2, 7, 3, 1, 1]
# 2        [5, 18, 18, 10, 80]     [2, 4, 1, 1, 1]
# 3                    [5, 18]              [2, 7]
# 4  [5, 18, 1200, 18, 10, 80]  [3, 4, 1, 2, 1, 1]
#
#                     Time_average                Time_minimum  \
# 0      [240, 540, 540, 180, 180]      [60, 540, 540, 10, 10]
# 1      [360, 120, 660, 120, 180]   [360, 120, 660, 120, 180]
# 2       [90, 180, 660, 480, 180]    [90, 180, 660, 480, 180]
# 3                      [30, 660]                   [30, 660]
# 4  [240, 360, 30, 660, 180, 360]  [90, 60, 30, 660, 180, 60]
#
#                       ST_FW1                           ET_FW1  \
# 0   [1080, 0, 0, 1080, 1080]     [1260, 360, 360, 1260, 1260]
# 1   [0, 1080, 0, 1080, 1080]     [360, 1260, 360, 1440, 1440]
# 2    [360, 1080, 0, 0, 1080]      [540, 1440, 360, 360, 1260]
# 3                  [1080, 0]                      [1440, 360]
# 4  [0, 0, 360, 0, 1080, 360]  [360, 360, 540, 360, 1440, 540]
#
#                            ST_FW2                          ET_FW2  \
# 0        [0, 1080, 1080, 1440, 0]           [0, 1440, 1440, 0, 0]
# 1           [1260, 0, 1080, 0, 0]           [1440, 0, 1440, 0, 0]
# 2           [0, 0, 1080, 1080, 0]           [0, 0, 1440, 1440, 0]
# 3                       [0, 1080]                       [0, 1440]
# 4  [1080, 1080, 0, 1080, 0, 1080]  [1440, 1260, 0, 1440, 0, 1260]
#
#                          Comments
# 0       [nan, nan, nan, nan, nan]
# 1       [nan, nan, nan, nan, nan]
# 2       [nan, nan, nan, nan, nan]
# 3                      [nan, nan]
# 4  [nan, nan, 1.0, nan, nan, nan]

# %%
Appliances = Appliances.new_feature("Presence_phone_charger",appliances_modifiers.presence_appliances("Item", "Charger"))

Appliances = Appliances.new_feature("Presence_iron",appliances_modifiers.presence_appliances("Item", "Iron"))

Appliances = Appliances.new_feature("Presence_TV",appliances_modifiers.presence_appliances("Item", "TV"))

Appliances = Appliances.new_feature("Presence_refrigerator/freezer",
                                    appliances_modifiers.presence_appliances("Item", "Refrigerator"))


Appliances = Appliances.new_feature("Presence_stereo", lambda x: 0)
Appliances = Appliances.new_feature("Presence_radio", appliances_modifiers.presence_appliances("Item", "Radio"))
Appliances = Appliances.new_feature("Presence_radio/stereo",
                                    common_modifiers.multi_unify_presence(
                                        ['Presence_radio', 'Presence_stereo']))

Appliances = Appliances.new_feature("Presence_DVD_player", lambda  x: 0)
Appliances = Appliances.new_feature("Presence_fan", lambda  x: 0)

Appliances = Appliances.select([
    ID_COL, "Presence_phone_charger", "Presence_iron", "Presence_TV", "Presence_refrigerator/freezer",
    "Presence_radio/stereo", "Presence_DVD_player", "Presence_fan"
])

Appliances.preview()
# Out:
#            ID  Presence_phone_charger  Presence_iron  Presence_TV  \
# 0  Q_EE_HH_01                       1              0            1
# 1  Q_EE_HH_02                       1              0            1
# 2  Q_EE_HH_03                       1              0            1
# 3  Q_EE_HH_04                       1              0            0
# 4  Q_EE_HH_05                       1              1            1
#
#    Presence_refrigerator/freezer  Presence_radio/stereo  Presence_DVD_player  \
# 0                              0                      1                    0
# 1                              0                      1                    0
# 2                              0                      1                    0
# 3                              0                      0                    0
# 4                              0                      1                    0
#
#    Presence_fan
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
CEFA_2016_EE = Q_Results_General.merge(Appliances, ID_COL)

CEFA_2016_EE = CEFA_2016_EE.apply(common_modifiers.rename({
    ID_COL: "ID"
}))
CEFA_2016_EE = CEFA_2016_EE.apply(common_modifiers.add_const_driver_many({
    "Hours_available_electricity": np.nan,
    "Years_of_HHH_in_community": np.nan,
    'Dwelling_quality_index': np.nan,
    'Age_HHH': np.nan,
    'HH_with_home_business': np.nan,
    'Ownership_motorized_vehicle': np.nan,
    'Ownership_small_livestock': np.nan,
    'Clean_fuel': np.nan,
    'Ownership_large_livestock': np.nan,
}))
CEFA_2016_EE = CEFA_2016_EE.select(["ID"] + constants.DRIVERS_LIST + constants.PRESENCE_LIST)
CEFA_2016_EE.preview()
# Out:
#            ID  Years_of_HHH_in_community  Dwelling_quality_index  \
# 0  Q_EE_HH_01                        NaN                     NaN
# 1  Q_EE_HH_02                        NaN                     NaN
# 2  Q_EE_HH_03                        NaN                     NaN
# 3  Q_EE_HH_04                        NaN                     NaN
# 4  Q_EE_HH_05                        NaN                     NaN
#
#    Hours_available_electricity  Measurement_age  Monthly_expenditure  \
# 0                          NaN                2              10000.0
# 1                          NaN                2             100000.0
# 2                          NaN                2              20000.0
# 3                          NaN                2             100000.0
# 4                          NaN                2              40000.0
#
#    Number_of_rooms  Climate_zone_lev_1  Climate_zone_lev_2  Age_HHH  ...  \
# 0             10.0                  12                  12      NaN  ...
# 1              7.0                  12                  12      NaN  ...
# 2              4.0                  12                  12      NaN  ...
# 3              7.0                  12                  12      NaN  ...
# 4              4.0                  12                  12      NaN  ...
#
#    Ownership_large_livestock Clean_fuel Tariff_payment_frequency  \
# 0                        NaN        NaN                  Monthly
# 1                        NaN        NaN                  Monthly
# 2                        NaN        NaN                  Monthly
# 3                        NaN        NaN                  Monthly
# 4                        NaN        NaN                  Monthly
#
#    Presence_refrigerator/freezer  Presence_iron  Presence_fan  \
# 0                              0              0             0
# 1                              0              0             0
# 2                              0              0             0
# 3                              0              0             0
# 4                              0              1             0
#
#    Presence_DVD_player  Presence_radio/stereo Presence_phone_charger  \
# 0                    0                      1                      1
# 1                    0                      1                      1
# 2                    0                      1                      1
# 3                    0                      0                      1
# 4                    0                      1                      1
#
#    Presence_TV
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1
#
# [5 rows x 26 columns]

# %%
CEFA_2016_EE.to_csv(root.joinpath("CEFA_2016_EE.csv"))
